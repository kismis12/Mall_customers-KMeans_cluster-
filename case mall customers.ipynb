# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ## as we see there is no null value or missing value in the data

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df1=df.drop("CustomerID",axis=1)

# %%
df1
# Out:
#       Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df.Genre.value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %%
sns.countplot(df.Genre)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
data=[112,88]
labels=['female','male']
plt.pie(data,labels=labels,autopct="%0.1f%%")
plt.title("%age of male and female",fontsize=18)
# Out:
# Text(0.5, 1.0, '%age of male and female')

# %% [markdown]
# ## we conclude that no. of females are more than males

# %%
sns.histplot(df.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.set(style='whitegrid')
sns.distplot(df['Age'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(12,9))
sns.countplot(df['Age'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ## there is more persons of age between 30-35 who are going to mall regularly or more and senior citizens visits tha mall least.From the countplot we confer that people of age group   27-32 visits mall more frequently and people of age group 55,56,64,69 visits least of all.

# %%
plt.figure(figsize=(12,9))
sns.barplot(x="Age",y="Annual Income (k$)",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
plt.figure(figsize=(18,9))
sns.countplot(df['Annual Income (k$)'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='count'>

# %%
sns.set(style='whitegrid')
sns.distplot(df['Annual Income (k$)'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Density'>

# %% [markdown]
# ## from distplot we conclude that most of the people have eanings from 50-75 dollars and from count plot people of age group 54 and 78 have max. annual income and also people having age group of 64 earns the least and of 41 highest and of range 27-41 have average or more earnings

# %%
plt.figure(figsize=(18,9))
sns.countplot(df['Spending Score (1-100)'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Spending Score (1-100)', ylabel='count'>

# %%
plt.figure(figsize=(12,9))
sns.barplot(x="Age",y="Spending Score (1-100)",data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Spending Score (1-100)'>

# %% [markdown]
# ## most of the people have their spending score in the range of 35-60 and people of age group in the range 18-39 have good spending score and people of age group 64 spend the the least

# %%
sns.boxplot(df['Genre'],df['Spending Score (1-100)'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='Spending Score (1-100)'>

# %% [markdown]
# ## we see that male have spending score of around 25-70 and females have 35-75 which concludes that females shops more

# %%
sns.boxplot(df['Genre'],df['Annual Income (k$)'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='Annual Income (k$)'>

# %% [markdown]
# ## some males paided more than females

# %%
df1.corr()
# Out:
#                              Age  Annual Income (k$)  Spending Score (1-100)
# Age                     1.000000           -0.012398               -0.327227
# Annual Income (k$)     -0.012398            1.000000                0.009903
# Spending Score (1-100) -0.327227            0.009903                1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## we see that there is no good correlation among them as they are shown by the dark colours

# %%
sns.pairplot(df1)

# %%
plt.figure(figsize=(16,9))
sns.barplot(x="Annual Income (k$)",y="Spending Score (1-100)",data=df1)
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %% [markdown]
# ## this can be more similar data but person having annual income of 69 dollar have more spending score of 75

# %%
sns.scatterplot(x="Annual Income (k$)",y="Spending Score (1-100)",data=df1,hue="Genre")
# Out:
# <AxesSubplot:xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
jk= LabelEncoder()

# %%
df1.Genre=jk.fit_transform(df1.Genre)

# %%
df1.head()
# Out:
#    Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      1   19                  15                      39
# 1      1   21                  15                      81
# 2      0   20                  16                       6
# 3      0   23                  16                      77
# 4      0   31                  17                      40

# %%
ss= StandardScaler()

# %%
xx=ss.fit_transform(df1)

# %%
x=pd.DataFrame(data=xx,columns=df1.columns)

# %%
x.head()
# Out:
#       Genre       Age  Annual Income (k$)  Spending Score (1-100)
# 0  1.128152 -1.424569           -1.738999               -0.434801
# 1  1.128152 -1.281035           -1.738999                1.195704
# 2 -0.886405 -1.352802           -1.700830               -1.715913
# 3 -0.886405 -1.137502           -1.700830                1.040418
# 4 -0.886405 -0.563369           -1.662660               -0.395980

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans()

# %%
lis=[]
for i in range(1,10):
    model=KMeans(i)
    model.fit(df1)
    lis.append(model.inertia_)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
lis
# Out:
# [308862.06000000006,
#  212889.44245524294,
#  143391.59236035674,
#  104414.67534220174,
#  75399.61541401486,
#  58350.654494628165,
#  51147.01731797612,
#  44359.6346411483,
#  40891.680830865036]

# %%
plt.plot(range(1,10),lis,marker='o')

# %%
from sklearn.cluster import KMeans

# %%
model1=KMeans(5)

# %%
model1.fit(df1)
# Out:
# KMeans(n_clusters=5)

# %%
plt.scatter(x='Annual Income (k$)',y='Spending Score (1-100)',data=df1,c=model1.labels_)

# %%
plt.scatter(x='Annual Income (k$)',y='Spending Score (1-100)',data=x,c=model1.labels_)

# %%
df1['cluster']=model1.labels_

# %%
df1
# Out:
#      Genre  Age  Annual Income (k$)  Spending Score (1-100)  cluster
# 0        1   19                  15                      39        0
# 1        1   21                  15                      81        4
# 2        0   20                  16                       6        0
# 3        0   23                  16                      77        4
# 4        0   31                  17                      40        0
# ..     ...  ...                 ...                     ...      ...
# 195      0   35                 120                      79        1
# 196      0   45                 126                      28        2
# 197      1   32                 126                      74        1
# 198      1   32                 137                      18        2
# 199      1   30                 137                      83        1
#
# [200 rows x 5 columns]

# %%
df1.groupby('cluster').mean()
# Out:
#             Genre        Age  Annual Income (k$)  Spending Score (1-100)
# cluster
# 0        0.391304  45.217391           26.304348               20.913043
# 1        0.461538  32.692308           86.538462               82.128205
# 2        0.513514  40.324324           87.432432               18.189189
# 3        0.423077  43.282051           55.025641               49.692308
# 4        0.391304  25.521739           26.304348               78.565217
